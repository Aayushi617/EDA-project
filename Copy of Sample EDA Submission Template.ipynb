# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Ayushi Sunil Bansod

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# **Project Summary: Airbnb Bookings Analysis**
#
# **Project Name:** Airbnb Bookings Analysis for Market Insights and Operational Optimization
#
# **Objective:**
# The primary objective of this project is to analyze Airbnb booking data to extract valuable insights that will help in understanding market trends, customer preferences, and operational performance. The analysis aims to identify key factors influencing booking patterns, revenue generation, and user behavior, with the goal of improving pricing strategies, customer acquisition, and overall platform performance.
#
# **Scope:**
# 1. **Data Collection & Integration:**
#    - Gather historical booking data, including user demographics, location, booking frequency, pricing, property types, and review scores.
#    - Integrate data from multiple sources such as Airbnb's internal databases, user feedback, and external market data for comprehensive analysis.
#
# 2. **Trend Analysis:**
#    - Identify seasonal trends and peak booking periods across different regions.
#    - Analyze the impact of external factors (e.g., holidays, events, economic conditions) on booking behavior and occupancy rates.
#
# 3. **Customer Segmentation:**
#    - Segment users based on booking behavior, preferences, and demographics to better understand target audiences.
#    - Create user personas for marketing teams to tailor communication and promotional efforts more effectively.
#
# 4. **Revenue Optimization:**
#    - Analyze pricing strategies and occupancy rates to identify potential opportunities for dynamic pricing or adjustments to maximize revenue.
#    - Conduct competitive analysis comparing Airbnb's pricing and availability against similar platforms (e.g., Booking.com, VRBO).
#
# 5. **Performance Metrics & KPIs:**
#    - Track key performance indicators (KPIs) such as booking conversion rate, average daily rate (ADR), length of stay, and cancellation rates.
#    - Measure the impact of guest reviews and ratings on booking decisions.
#
# 6. **Predictive Analytics:**
#    - Utilize machine learning techniques to forecast booking demand and pricing trends.
#    - Predict factors that can drive future bookings, such as property amenities, location, and review scores.
#
# 7. **Reporting & Visualization:**
#    - Create interactive dashboards and reports for Airbnb’s stakeholders, highlighting insights and trends.
#    - Provide actionable recommendations for improving booking strategies, customer engagement, and revenue growth.
#
# **Timeline:**
# - **Phase 1**: Data Collection & Preprocessing (1 month) – Gather and clean raw booking data from Airbnb.
# - **Phase 2**: Exploratory Data Analysis & Trend Identification (2 months) – Conduct in-depth analysis to identify key trends and patterns.
# - **Phase 3**: Customer Segmentation & Pricing Analysis (2 months) – Perform segmentation and pricing analysis for actionable insights.
# - **Phase 4**: Predictive Modeling & Reporting (1 month) – Develop predictive models and create visualizations.
# - **Phase 5**: Final Report & Recommendations (1 month) – Prepare a comprehensive report with actionable insights and suggestions.
#
# **Expected Outcomes:**
# - A clearer understanding of user booking behaviors and trends.
# - Data-driven pricing recommendations to optimize revenue.
# - Enhanced segmentation for personalized marketing campaigns.
# - Improved resource allocation for property hosts based on demand forecasts.
# - Insights for Airbnb to refine their customer acquisition strategies and operational efficiencies.
#
# **Budget:** Estimated $400,000 for data gathering, analysis tools, team resources, and report generation.
#
# **Success Metrics:**
# - Increased booking conversion rates driven by data-informed pricing and marketing strategies.
# - Improved accuracy of demand forecasts and better resource planning.
# - Higher engagement from hosts and guests due to targeted recommendations and personalized experiences.
# - Actionable insights contributing to revenue growth and platform optimization.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# **Problem Statement: Airbnb Bookings Analysis**
#
# Airbnb operates in a highly competitive and dynamic market, with millions of hosts and guests interacting on its platform. While Airbnb collects vast amounts of data related to bookings, user behavior, and market conditions, it lacks a centralized, in-depth analysis of this data that can drive optimized decision-making across various functions, including pricing, marketing, and customer engagement.
#
# Specifically, Airbnb faces the following challenges:
#
# 1. **Unoptimized Pricing Strategy:** Despite having extensive data on booking trends, Airbnb’s pricing strategy may not fully reflect market demand, customer behavior, or competitor pricing, leading to missed revenue opportunities for hosts and the platform.
#
# 2. **Limited Customer Insights:** Airbnb lacks a granular understanding of customer preferences, booking patterns, and behaviors across various segments, which hampers its ability to deliver personalized experiences and targeted marketing initiatives.
#
# 3. **Seasonality and Market Fluctuations:** Airbnb is unable to predict seasonal trends, external factors, and market fluctuations with high accuracy, resulting in inefficient resource allocation and missed opportunities during peak periods or special events.
#
# 4. **Inefficient Resource Planning:** Hosts and Airbnb’s internal teams may not have access to actionable insights that would help them anticipate demand, optimize property availability, and make data-driven operational decisions.
#
# 5. **Suboptimal User Experience:** Despite having user feedback in the form of reviews and ratings, there is a gap in leveraging these insights to enhance the guest experience or encourage repeat bookings.
#
# This project aims to address these challenges by conducting a comprehensive analysis of Airbnb's booking data to derive actionable insights that will help optimize pricing strategies, improve customer segmentation, enhance operational efficiency, and drive overall platform performance. By leveraging data-driven solutions, Airbnb can improve its competitive position, increase revenue for hosts, and enhance the overall user experience for both guests and hosts.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Business Objective: Airbnb Bookings Analysis**
#
# The primary business objective of this project is to leverage data analytics to optimize Airbnb’s pricing strategy, customer segmentation, and operational decision-making in order to drive revenue growth, improve user experience, and enhance platform efficiency. By analyzing booking data, customer behavior, and market trends, the goal is to provide actionable insights that can directly contribute to Airbnb's competitive advantage in the online travel and accommodation market.
#
# Key objectives include:
#
# 1. **Optimize Pricing Strategy:**
#    - Develop data-driven pricing models that account for demand fluctuations, competitor pricing, seasonal trends, and guest preferences, allowing Airbnb to maximize revenue for hosts and the platform.
#
# 2. **Enhance Customer Segmentation & Personalization:**
#    - Identify distinct customer segments based on booking behavior and preferences, enabling more targeted marketing efforts and personalized experiences that drive guest engagement and loyalty.
#
# 3. **Forecast Market Trends & Demand:**
#    - Utilize historical booking data to predict market trends, peak demand periods, and the impact of external factors, enabling better resource planning, pricing adjustments, and inventory management for hosts.
#
# 4. **Improve Operational Efficiency:**
#    - Provide insights that help Airbnb optimize its internal processes, such as demand forecasting for resource allocation and improving the responsiveness of customer service operations during high-demand periods.
#
# 5. **Increase Revenue & Profitability:**
#    - Use insights from data analysis to develop strategies that increase the booking conversion rate, reduce cancellations, and enhance the guest experience, all contributing to higher revenue for both hosts and Airbnb.
#
# 6. **Enhance User Experience:**
#    - Leverage customer feedback and behavioral insights to improve the overall user journey on the platform, increasing satisfaction and encouraging repeat bookings.
#
# By achieving these objectives, Airbnb can strengthen its position in the market, drive higher revenue for hosts, enhance customer satisfaction, and ultimately increase its market share in the highly competitive travel and accommodation industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data=pd.read_csv('/content/drive/MyDrive/Airbnb_project/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(data[data.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(),cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset appears to be an Airbnb listing dataset for New York City from 2019. It contains 48,895 entries and 16 columns, including:
#
# ## *Basic Listing Details:*
#
# * id: Unique listing ID
# * name: Name of the listing
# * host_id: Unique ID of the host
# * host_name: Name of the host
# ## *Location Information:*
#
# * neighbourhood_group: Borough of NYC (e.g., Manhattan, Brooklyn)
# * neighbourhood: Specific neighborhood
# * latitude, longitude: Geographic coordinates
# ## *Property Details:*
#
# * room_type: Type of room (e.g., entire home, private room)
# * price: Price per night
# * minimum_nights: Minimum nights required for booking
# * availability_365: Number of available days in a year
# ## *Review Data:*
#
# * number_of_reviews: Total reviews received
# * last_review: Date of the last review
# * reviews_per_month: Average monthly reviews
# ## *Host Metrics:*
#
# * calculated_host_listings_count: Number of listings by the same host**
# There are some missing values in name, host_name, last_review, and reviews_per_month. Let me know if you want specific analyses, such as price trends, availability patterns, or neighborhood insights! ​

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns

# %%
# Dataset Describe
data.describe(include="all")

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * id - Unique identifier for each listing
# * name-	Name/title of the Airbnb listing
# * host_id -	Unique identifier for the host
# * host_name -	Name of the host
# * neighbourhood_group -	Borough of New York City (Manhattan, Brooklyn, Queens, Bronx, Staten Island)
# * neighbourhood -	Specific neighborhood where the listing is located
# * latitude -	Geographic latitude of the listing
# * longitude -	Geographic longitude of the listing
# * room_type -	Type of room offered (Entire home/apt, Private room, Shared room)
# * price -	Price per night in USD
# * minimum_nights -	Minimum number of nights required for a booking
# * number_of_reviews -	Total number of reviews received
# * last_review -	Date of the most recent review
# * reviews_per_month -	Average number of reviews per month
# * calculated_host_listings_count -	Total number of listings hosted by the same host
# * availability_365 -	Number of days the listing is available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in data.columns.tolist():
  print("Number of unique values in",i,"=",data[i].nunique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#It is used to find number of rows and columns
data.shape

# %%
# It is used to display first 5 rows or display n rows
data.head()

# %%
# It is used to find last 5 rows
data.tail()

# %%
# It is used to find data type of each column
data.dtypes

# %%
# used to find memory usage
data.info()

# %%
# used to get all column names
data.columns

# %%
# used to fetch only numerical values
num_data=data.select_dtypes(include=['int64','float64'])
num_data.columns

# %%
# fetct categorical/text columns
cat_data=data.select_dtypes(include=['object'])
cat_data.columns

# %%
# used to find distinct values in a categorical column
data.loc[:,'id'].unique()

# data.loc[:,'reversed_room_type'].unique()
# data.loc[:,'meal'].unique()
# data.loc[:,'market_segment'].unique()
# data.loc[:,'distribution_channel'].unique()
# data.loc[:,'deposit_type'].unique()
# data.loc[:,'costomer_type'].unique()
# data.loc[:,'reservation_status'].unique()
# data.loc[:,'hotel'].unique()
# data.loc[:,'country'].unique()
# data.loc[:,'arrival_date_month'].unique()

# %%
# find the value count of number_of_reviews
data.loc[:,'number_of_reviews'].value_counts()

# %%
# used to find statistical report
data.describe()

# %%
# used to rename column names
data.rename({'hotel':'hotel_type'},axis=1,inplace=True)
data

# %%
# used to arrange data in increasing
data.sort_values('host_name',ignore_index=True,inplace=True)
data

# %%
# used to arrange data in increasing or decreasing
data.sort_values('host_name',ascending=False,ignore_index=True,inplace=True)
data

# %%
# fetch all the hotel_types

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# 1. Distribution of price
plt.figure(figsize=(5,3))
sns.histplot(x=data['price'],bins=10,kde=True,color='green')
plt.title("Distribution of prices($)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram helps visualize the distribution of numerical data by grouping it into intervals or bins. This can provide insights into how the data is spread across a range, such as whether it is skewed, symmetrical, or has multiple peaks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings are priced under $200 per night, with a few extreme outliers skewing towards luxury pricing.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can contribute to positive business growth by enabling:
#
# * Optimized Pricing Strategy – Hosts can set competitive prices based on market trends.
# * Market Positioning – Understanding price distribution helps in targeting the right customer segments.
# * Revenue Maximization – Identifying underpriced properties allows for pricing adjustments to increase earnings.
# * Targeted Marketing – Knowing that most bookings occur in a specific price range allows tailored promotions.
#
# Some insights could indicate potential risks that might slow down growth:
#
# ###*High-Price Outliers May Struggle with Bookings*
#
# * Listings priced significantly higher than the market average may have low demand due to customer price sensitivity.
# * If luxury properties are not differentiated with unique offerings, they may remain vacant for extended periods.
# ###*Oversaturation in the Low-Price Segment*
#
# * The histogram suggests a large concentration of listings in the lower price range.
# * This could lead to price wars among hosts, reducing profitability as competition forces prices downward.
# ###*Revenue Loss Due to Underpricing*
#
# * Some hosts may be undervaluing their properties, missing out on potential revenue.
# * If demand is strong but prices are too low, businesses may not be maximizing their earning potential.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Distribution of latitude
plt.figure(figsize=(5,3))
sns.boxplot(x=data['latitude'],color='blue')
plt.title('Distribution is latitude')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  It is one of the best ways to visualize spread, central tendency, and outliers in a single dimension (latitude).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The box represents the Interquartile Range (IQR) (middle 50% of the data), making it easy to see where most Airbnb listings are located.
# * The whiskers extend to show the range of data, while outliers (dots beyond the whiskers) indicate properties in less common locations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * The boxplot shows a concentration of listings in a specific latitude range, likely representing high-demand areas like Manhattan and Brooklyn.
# * Hosts can price properties in these areas higher due to demand, maximizing revenue.
# * Investors can focus on buying properties in prime latitudes for better ROI.
#
# Negative Growth:
# * Listings in extreme latitudes may suffer from low visibility and fewer bookings compared to central locations.
# * Hosts in these areas may need to offer discounts or extra services to attract guests, potentially reducing profitability.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# 3. Distribution of neighbourhood groups
plt.figure(figsize=(6,2))
sns.countplot(x=data['neighbourhood_group'],palette='rainbow')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is the best way to visualize how Airbnb listings are distributed across different neighbourhood groups.It clears the comparision of categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan Has the Highest Number of Listings
# * Brooklyn is the Second Most Popular Area
# * Lower Listings in Queens, The Bronx, and Staten Island

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * Manhattan and Brooklyn have the highest number of listings, indicating strong demand.
# * Hosts in these areas can charge premium prices, as they are hotspots for tourists and business travelers.
# * Queens, The Bronx, and Staten Island have fewer listings, suggesting less competition.
# * Hosts can attract budget-conscious travelers by offering lower prices or unique experiences.
#
# Negative Growth:
# * Over-Saturation in High-Demand Areas
# * Lower Demand in certain area = Higher vacancy risk.
# * Potential price wars in Competitive Neighbourhoods

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Number of reviews Distribution
plt.figure(figsize=(5,3))
sns.kdeplot(x=data['number_of_reviews'],color='red')
plt.title("Distribution of Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It shows the distribution shape
# * It highlights skewness
# * It avoids binning issues
# * The KDE plot provides a amooth curve that makes it easy to interpret patterns without exessive noise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A significant number of listings have fewer than 100 reviews, with many having only a few. Only a few listings have a very high number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Business Impact:
#
#  Identifying Popular Listings – Listings with a high number of reviews indicate strong customer interest. Hosts can analyze what makes them successful (pricing, location, amenities) and replicate those strategies.
#
#  Understanding Market Demand – If many listings have low reviews, it may indicate slow demand. This insight can help optimize pricing, marketing, or service offerings.
#
#  Improving Customer Experience – Listings with high reviews but negative ratings can highlight pain points (e.g., cleanliness, service). Addressing these can boost customer satisfaction and repeat bookings.
#
# * Negative Growth:
#
#  Highly Skewed Review Distribution – If a few listings dominate with thousands of reviews while most get very few, it suggests market saturation. New hosts might struggle to attract guests, discouraging new listings and hurting long-term growth.
#
#  Declining Engagement – If many listings have zero or very few reviews, it could indicate guests are not leaving feedback, possibly due to bad experiences or lack of incentives. This could hurt future bookings.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Minimun nights required Distribution
plt.figure(figsize=(5,3))
sns.histplot(x=data['minimum_nights'],bins = 50,kde=True,color='green')
plt.title(" Minimun nights required Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The histogram shows the frequency of different minimum_nights values, helping us see the overall distribution.
# * The KDE curve helps smooth out the distribution and highlight trends, making it easier to spot long tails or unusual spikes in the data.
# * Since minimum_nights is a numerical variable, a histogram is a natural choice to visualize how values are spread.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings have a minimum night stay requirement between 1 and 3 nights, with a few requiring longer stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * If most listings have low minimum night requirements (e.g., 1-3 nights), Airbnb hosts can attract more short-term guests, such as tourists or business travelers, maximizing occupancy rates.
# * Flexible minimum stay policies can cater to a wider audience, making it easier for guests to book, leading to better reviews and higher rankings in Airbnb’s search results.
#
# Negative growth Impact:
# * If a significant number of listings require a high minimum stay (e.g., 7+ nights), it could discourage short-term travelers, leading to lower occupancy and lost revenue opportunities.
# * Cities like NYC have short-term rental regulations, where listings with high minimum nights might be avoiding local laws rather than optimizing revenue.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Distribution of Longitude
plt.figure(figsize=(5,3))
sns.histplot(x=data['longitude'],bins=10,kde=True,color='green')
plt.title("Distribution of Longitude")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Since longitude is a continuous numerical variable, a histogram helps visualize how listings are distributed along the east-west axis of New York City.
# * If the histogram shows peaks, it suggests that many listings are concentrated within specific longitude ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The longitude values are concentrated within a specific range, indicating that listings are mostly clustered within certain parts of New York City.
# * The KDE curve suggests a bimodal or skewed distribution, possibly reflecting the geographic spread of listings across different boroughs (e.g., Manhattan vs. Brooklyn).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * If most listings are concentrated within a specific longitude range, it indicates high Airbnb activity in those areas (e.g., Manhattan).
# * Airbnb can incentivize hosts in less crowded neighborhoods to balance demand and supply.
# * By correlating longitude with pricing and occupancy rates, hosts can adjust pricing strategies based on location-driven demand.
#
# Negative Growth Impact:
# * If the distribution is heavily skewed toward a narrow longitude range, it may indicate overcrowding in those areas.
# * This could lead to intense competition, lower prices, and decreasing revenue per listing.
# * If the distribution shows very few listings in outer boroughs (e.g., Bronx, Staten Island), Airbnb may be missing out on potential growth markets.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Availability vs room type
plt.figure(figsize=(5,3))
sns.barplot(data=data ,x ='room_type' , y='availability_365')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * We are analyzing the availability_365 for different room_type categories, making a bar plot a good fit.
# * sns.barplot() automatically calculates the mean (by default) of availability_365 for each room_type, which helps understand trends across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * If entire homes have significantly lower availability than private or shared rooms, it might suggest that they are listed by occasional hosts rather than full-time rental businesses.
#
# * The trends could hint at how hosts manage their listings, whether they limit availability due to regulations, personal use, or demand fluctuations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * If entire homes/apartments show lower availability, this could indicate higher demand. Investors or hosts might increase supply in that segment, improving revenue potential.
# *  If shared rooms have high availability but lower demand, platforms like Airbnb can adjust marketing strategies to improve occupancy rates.
#
# Negative Growth:
# * If entire homes have lower availability, travelers preferring full apartments might turn to competitors (e.g., hotels, serviced apartments), causing lost revenue.
# * If private and shared rooms are always available but not fully booked, it may signal an oversupply issue, leading to price drops and reduced profitability for hosts.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Reviews per month vs room type
plt.figure(figsize=(6,3))
sns.violinplot(data=data , x='room_type',y='reviews_per_month')
plt.title('Relationship between Room type and Reviews per month')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is a great choice because it shows both the distribution and density of reviews per month for each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Private rooms tend to have a wider distribution of reviews per month, meaning some get very frequent reviews while others get fewer.
# * Entire homes/apartments have a lower median number of reviews, likely because they are booked for longer stays or have fewer frequent guests.
# * Shared rooms seem to have a lower but consistent number of reviews, possibly due to lower demand or fewer listings.
# * Outliers – Some listings receive significantly more reviews per month than the average, which could indicate high-demand properties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * The high distribution of reviews for private rooms suggests they receive frequent bookings. New hosts may benefit from listing private rooms to maximize occupancy and earnings.
# * Since entire homes/apartments tend to have fewer but steady reviews, Airbnb could focus on promoting them for long-term stays, targeting remote workers or families.
#
# Negative Growth:
# * While private rooms have a wide distribution of reviews, it could also indicate high competition among listings. If many private rooms exist in a given market, prices may drop due to oversupply.
# * The plot shows that shared rooms generally receive fewer reviews, which may suggest lower bookings. This could mean shared rooms are less attractive to guests, limiting revenue for hosts in this category.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Minimum nights v/s Room Type
plt.figure(figsize=(10,3))
barplot=sns.barplot(data=data ,x ='room_type' , y='minimum_nights',palette='rainbow',hue='neighbourhood_group')
plt.xticks(rotation=90)
plt.title("Average Minimum nights by room type")
for bars in barplot.containers:
   barplot.bar_label(bars)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing discrete categories (room types) based on a numerical value (minimum nights).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Entire homes/apartments might have a slightly higher minimum stay compared to private or shared rooms, as hosts may prefer longer bookings to reduce turnover costs.
# * If certain neighborhood groups have higher bars, it indicates that hosts in those areas generally require more nights as a minimum stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact:
# * By adjusting minimum night requirements to match market demand, hosts can increase occupancy rates and reduce vacancies.
# * Longer stays in some boroughs: If boroughs like Staten Island have a higher minimum stay, it may indicate demand for long-term travelers (e.g., business travelers, students). Hosts in these areas could target these customer segments through marketing.
#
# Negative Growth:
# * If certain boroughs or room types require long stays (e.g., 7+ nights), casual travelers or tourists may avoid booking and look for alternatives.
# * If data shows that guests prefer shorter stays (2–3 nights) but a borough has a high minimum requirement (e.g., 5+ nights), then Airbnb and hosts are missing out on potential revenue from short-term travelers.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Price with respect to Neighbourhood group and Room type
plt.figure(figsize=(12,8))
sns.barplot(data=data , x='neighbourhood_group',y='price',hue='room_type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It effectively compares the average price across different neighbourhood groups while also differentiating by room type.The hue='room_type' parameter allows us to compare multiple categories (room types) within each neighborhood group, making it easy to spot patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the highest average prices – Regardless of room type, listings in Manhattan tend to be the most expensive compared to other boroughs.
# * Entire Home/Apt is the most expensive room type – In all boroughs, entire homes/apartments have a significantly higher average price than private or shared rooms.
# * Price variations within boroughs – While Manhattan has a high price overall, the variation among room types suggests that private and shared rooms are relatively more affordable compared to entire apartments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact-
# * Since Manhattan has the highest average price, hosts in this area can charge premium rates for entire homes/apartments, especially in high-demand neighborhoods.
# * Since entire homes/apartments have the highest prices across all boroughs, property investors should consider focusing on whole-unit rentals rather than private or shared rooms.
#
# Negative Growth-
# * If hosts in Staten Island or The Bronx price their listings too high (trying to match Manhattan prices), they may experience low bookings and revenue loss.
# * Since private and shared rooms are priced significantly lower than entire homes, hosts may struggle to get enough bookings to remain profitable.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Calculated host listings v/s Neighbourhood Group
plt.figure(figsize=(6,3))
sns.violinplot(data=data , x='calculated_host_listings_count',y='neighbourhood_group')
plt.title(" Calculated host listings v/s Neighbourhood Group")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it is one of the best ways to visualize the distribution and density of a numerical variable (calculated host listings count) across different categories (neighbourhood groups).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The majority of hosts in all boroughs have fewer listings (closer to 1-2 properties), as seen from the density in the lower range.
# * Some hosts in Manhattan, Brooklyn, and Queens have a high number of listings, suggesting professional hosts or property managers running multiple listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Growth Impact:
# * The Bronx and Staten Island have fewer large-scale hosts, meaning less competition for new Airbnb hosts.
# * Manhattan and Brooklyn have a high concentration of multi-listing hosts.
#
# Negative Growth:
# * The high number of multi-listing hosts in Manhattan and Brooklyn suggests fierce competition.
# * Risk: New hosts entering these markets may struggle to attract bookings unless they offer something unique.
# * Justification: If supply exceeds demand, prices could drop, reducing profitability for hosts.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Neighbourhood Group v/s Availability 365
plt.figure(figsize=(8,4))
plt.title("Availability of Listings per Year by Neighbourhood Group")
sns.boxplot(data=data , x='neighbourhood_group',y='availability_365')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It shows distribution – A boxplot provides a clear summary of the distribution of availability_365 across different neighbourhood_group categories, highlighting the median, quartiles, and potential outliers.
#
# * Comparison across categories – Since neighbourhood_group is a categorical variable, a boxplot effectively compares multiple groups side by side.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some neighbourhood groups have a higher median availability than others. For example, Manhattan and Brooklyn likely have a lower median availability compared to Staten Island or Queens.
# * There are a lot of outliers (dots above and below the whiskers), indicating that some listings are available almost all year round (365 days) while others have very limited availability.
# * If a neighbourhood group shows many listings with very low availability, it could mean that those areas have stricter rental laws, seasonal rentals, or owners who only occasionally rent out their space.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# * Targeted Marketing – Understanding which areas have more available listings can help in crafting marketing campaigns for different traveler segments.
# * Supply & Demand Insights – Identifying neighborhoods with consistently low availability suggests high demand, signaling an opportunity for new hosts or price adjustments.
#
# Negative Growth Factors:
# * Some areas may have restrictions on short-term rentals, causing artificially high availability (listings that exist but cannot be booked). This could discourage new hosts and reduce growth.
# * High availability but consistently low occupancy could suggest issues with host service quality, safety, or neighborhood desirability. If customers avoid specific areas, it can lead to declining demand over time.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Relationship between sales and profit
plt.figure(figsize=(8,6))
sns.scatterplot(data=data , x='latitude',y='longitude')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot because it's well-suited for visualizing geographical data using latitude and longitude. Each point represents a listing, and its position on the plot reflects its real-world location. This makes it easier to see patterns, clusters, and the overall distribution of Airbnb properties across NYC.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Concentration of Listings: There are dense clusters of Airbnb listings, particularly in areas like Manhattan and Brooklyn. This reflects their popularity among tourists and renters.
# * Sparse Listings: Outer boroughs such as Staten Island and parts of Queens have fewer listings, suggesting lower demand or stricter regulations.
# * Geographical Spread: The plot shows a clear geographic spread of listings across the city, with most properties located in central and easily accessible areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
# * Target High-Demand Areas: Clusters in Manhattan and Brooklyn indicate high demand, suggesting these areas are profitable for property investment or Airbnb hosting. Businesses can focus marketing efforts here to attract more guests.
# * Identify Untapped Markets: Less saturated areas, such as parts of Queens or Staten Island, might present opportunities to offer unique stays without much competition.
#
# Potential Negative Growth
# * Market Saturation: Overcrowded areas like Manhattan may face intense competition, making it harder for new listings to stand out, which could limit profitability.
# * Shifts in Demand: Sparse areas might indicate low demand, making it difficult to generate consistent bookings. Investing in these locations might result in lower returns.

# %%
df= data.select_dtypes(include=['int64','float64'])
df

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,8))
corr= df[['price', 'number_of_reviews', 'reviews_per_month', 'availability_365']].corr()
sns.heatmap(corr,annot=True,linewidths=0.5)
plt.title('Correlation Heatmap')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the heatmap because it's an effective way to visualize the correlation between multiple numerical variables. The color gradient quickly conveys the strength and direction of relationships, while the numerical annotations provide exact values. This makes it easy to identify both strong and weak correlations at a glance, helping businesses understand which factors might influence performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive Correlation Between Number of Reviews and Reviews per Month:
#
# * This strong positive correlation indicates that listings receiving frequent reviews tend to accumulate more total reviews over time. This suggests that consistently good service and high guest engagement lead to sustained success.
#
# Weak Correlation Between Price and Other Variables:
#
# * Price shows little to no correlation with the number of reviews, reviews per month, or availability. This implies that pricing may not directly influence guest feedback or booking frequency, suggesting other factors like location, property type, or amenities might play a more significant role.
#
# Moderate Correlation Between Availability and Reviews per Month:
#
# * The positive correlation suggests that listings available for more days in a year receive reviews more consistently. This aligns with the idea that greater availability increases the likelihood of bookings and, consequently, guest reviews.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
plt.figure(figsize=(10,8))
col=['price','number_of_reviews','reviews_per_month','availability_365']
sns.pairplot(data=df,vars=col,corner=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pair plot because it's great for visualizing relationships between multiple numerical variables at once. It provides scatter plots for each pair of variables and histograms for individual distributions, making it easy to identify patterns, correlations, and outliers. Using corner=True simplifies the chart by showing only the lower triangle, which keeps the visualization clean and easy to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Price vs. Number of Reviews: The plot shows a wide spread, with most listings priced lower and receiving more reviews. This indicates that affordable listings tend to attract more guests and generate more feedback.
# * Price vs. Reviews per Month: There’s no clear trend, suggesting that pricing doesn't strongly affect the frequency of reviews.
# * Availability vs. Reviews: Listings available for more days tend to receive more reviews, supporting the idea that increased availability leads to more bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
#  1. Focus on High-Demand Locations:
# * Insight: Listings are densely concentrated in Manhattan and Brooklyn, indicating high demand.
# * Recommendation: Invest in properties in these boroughs, particularly near tourist attractions and transport hubs, to maximize occupancy rates.
#
#  2. Optimize Pricing for More Bookings:
# * Insight: Price has a weak correlation with reviews and availability, suggesting competitive pricing won’t necessarily reduce reviews or bookings.
# * Recommendation: Use dynamic pricing to stay competitive during peak seasons while ensuring affordability to attract more guests.
#
#  3. Increase Availability to Boost Reviews and Bookings:
# * Insight: Properties with higher availability receive more reviews, indicating more bookings.
# * Recommendation: Maximize the number of available days to increase booking opportunities and guest feedback.
#
#  4. Improve Guest Experience to Gain More Reviews:
# * Insight: Listings with frequent reviews accumulate more overall reviews, suggesting that positive experiences lead to consistent feedback.
# * Recommendation: Focus on customer service, cleanliness, and amenities to encourage guests to leave positive reviews.
#
#  5. Be Aware of Market Saturation and Regulations:
# * Insight: High competition in popular areas may limit profitability, and NYC’s short-term rental regulations could impact occupancy rates.
# * Recommendation: Diversify investments by considering emerging neighborhoods in Queens or the Bronx and ensure c mpliance with local laws to avoid penalties.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of Airbnb NYC 2019 data provided valuable insights into the distribution, pricing, and performance of listings across the city. Key findings from scatter plots, correlation heatmaps, and pair plots revealed patterns that can help optimize business strategies for hosts and investors.
#
# * Location Matters: The majority of listings are concentrated in Manhattan and Brooklyn, highlighting these areas' popularity and high demand. While competition is intense, strategic investments in prime locations can yield consistent bookings.
# * Price Has Limited Influence: Pricing does not strongly correlate with the number of reviews or booking frequency, suggesting that factors like location, amenities, and guest experience play a more significant role.
# * Availability Drives Engagement: Listings available for more days per year receive more bookings and reviews, emphasizing the importance of maximizing availability to increase occupancy rates.
# * Guest Experience is Key: Positive guest experiences lead to more frequent reviews, which can enhance a listing’s visibility and credibility, driving long-term success.
#
# While high demand in central areas offers growth opportunities, market saturation and regulatory restrictions in New York City can pose challenges. To ensure sustainable growth, businesses should diversify their listings by exploring less competitive neighborhoods, optimizing pricing, and delivering exceptional guest experiences.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
